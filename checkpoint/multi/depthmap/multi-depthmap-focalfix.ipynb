# %%
# !git clone https://github.com/nkt780426/3d_face_recognition_magface.git
# Out:
# Cloning into '3d_face_recognition_magface'...
# remote: Enumerating objects: 601, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 601 (delta 38), reused 56 (delta 18), pack-reused 516 (from 1)
# Receiving objects: 100% (601/601), 98.30 MiB | 23.90 MiB/s, done.
# Resolving deltas: 100% (50/50), done.

# %%
# !mv 3d_face_recognition_magface/going_modular .

# %%
import warnings
warnings.filterwarnings("ignore")
from torch.optim import Adam
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
import albumentations as A
import os
import torch

from going_modular.dataloader.multitask import create_multitask_datafetcher
from going_modular.model.MTLFaceRecognition import MTLFaceRecognition
from going_modular.loss.MultiTaskLoss import MultiTaskLoss
from going_modular.train_eval.train import fit
from going_modular.utils.transforms import RandomResizedCropRect, GaussianNoise
from going_modular.utils.MultiMetricEarlyStopping import MultiMetricEarlyStopping
from going_modular.utils.ModelCheckPoint import ModelCheckpoint

device = "cuda" if torch.cuda.is_available() else "cpu"
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

# Đặt seed toàn cục
seed = 42
torch.manual_seed(seed)

CONFIGURATION = {
    'type': 'depthmap',
    
    # Thư mục
    'dataset_dir': '/kaggle/input/hoangvn-3dmultitask',
    'checkpoint_dir': './checkpoint/multi/',
    
    # Cấu hình train
    'device': device,
    'epochs': 119,
    'num_workers': 4,
    'batch_size': 16,
    'image_size': 256,
    'base_lr': 1e-4,
    
    # Cấu hình network
    'backbone': 'miresnet18',
    'embedding_size': 512,
    'num_classes': None,
    'loss_gender_weight': 30,
    'loss_da_gender_weight': 30,
    'loss_emotion_weight': 10,
    'loss_da_emotion_weight': 10,
    'loss_pose_weight': 30,
    'loss_da_pose_weight': 30,
    'loss_spectacles_weight': 10,
    'loss_da_spectacles_weight': 10,
    'loss_facial_hair_weight': 10,
    'loss_da_facial_hair_weight': 10,
}

CONFIGURATION['num_classes'] = len(os.listdir('/kaggle/input/hoangvn-3dmultitask/Albedo/train'))

train_transform = A.Compose([
    RandomResizedCropRect(256),
    GaussianNoise(),
], additional_targets={
    'albedo': 'image',
    'depthmap': 'image'
})


test_transform = A.Compose([
    A.Resize(height=CONFIGURATION['image_size'], width=CONFIGURATION['image_size'])
], additional_targets={
    'albedo': 'image',
    'depthmap': 'image'
})

train_dataloader, test_dataloader, train_weight_class = create_multitask_datafetcher(CONFIGURATION, train_transform, test_transform)
model = MTLFaceRecognition(CONFIGURATION['backbone'], CONFIGURATION['num_classes'])

criterion = MultiTaskLoss(os.path.join(CONFIGURATION['dataset_dir'], 'train_set.csv'), CONFIGURATION)
optimizer = Adam(model.parameters(), lr=CONFIGURATION['base_lr'])
# Khởi tạo scheduler
scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=40, T_mult=1, eta_min=1e-6)

earlystop_dir = os.path.abspath(CONFIGURATION['checkpoint_dir'] + CONFIGURATION['type'] + '/models')

early_stopping = MultiMetricEarlyStopping(
    monitor_keys=['cosine_auc', 'euclidean_auc'],
    patience=1000,
    mode='max',
    verbose=0,
    save_dir=earlystop_dir,
    start_from_epoch=0
)      
checkpoint_path = os.path.abspath(CONFIGURATION['checkpoint_dir'] + CONFIGURATION['type'] + '/models/checkpoint.pth')
modle_checkpoint = ModelCheckpoint(filepath=checkpoint_path, verbose=1)

# %%
fit(
    conf=CONFIGURATION,
    start_epoch=0,
    model=model,
    train_dataloader=train_dataloader, 
    test_dataloader=test_dataloader, 
    criterion=criterion,
    optimizer=optimizer,    
    scheduler=scheduler, 
    early_stopping=early_stopping,
    model_checkpoint=modle_checkpoint
)
# Out:
# Epoch 1:
# ╒═════════════════════╤════════════╤══════════════════════╕
# │ Metric              │      Train │ Test                 │
# ╞═════════════════════╪════════════╪══════════════════════╡
# │ loss                │ 68.0243    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_id             │ 21.0154    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_gender         │  0.0634941 │ 0.061810888815671206 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_gender      │  0.556848  │ 0.457437876611948    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_emotion        │  0.185936  │ 0.1905479710549116   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_emotion     │  0.336146  │ 0.369439072906971    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_pose           │  0.0207154 │ 0.019649158348329365 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_pose        │  0.0361212 │ 0.033771237125620246 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair    │  0.221641  │ 0.24889447540044785  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_facial_hair │  0.795856  │ 0.9769887961447239   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles     │  0.212624  │ 0.20635685324668884  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_spectacles  │  0.917152  │ 0.5603346526622772   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_gender          │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles      │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair     │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_pose            │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_emotion         │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine       │  0.571648  │ 0.5879289103481088   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean    │  0.601648  │ 0.6352138605072268   │
# ╘═════════════════════╧════════════╧══════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth
# Epoch 2:
# ╒═════════════════════╤════════════╤══════════════════════╕
# │ Metric              │      Train │ Test                 │
# ╞═════════════════════╪════════════╪══════════════════════╡
# │ loss                │ 65.3934    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_id             │ 21.1382    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_gender         │  0.0584326 │ 0.05846311943605542  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_gender      │  0.493231  │ 0.1448979265987873   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_emotion        │  0.183954  │ 0.18167138285934925  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_emotion     │  0.458768  │ 0.6745283529162407   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_pose           │  0.0196815 │ 0.020571329863741994 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_pose        │  0.0445172 │ 0.0626739333383739   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair    │  0.2184    │ 0.2396271824836731   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_facial_hair │  0.917436  │ 0.9726271517574787   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles     │  0.210015  │ 0.23132398165762424  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_spectacles  │  0.589365  │ 0.8144681267440319   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_gender          │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles      │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair     │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_pose            │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_emotion         │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine       │  0.585061  │ 0.5768346405897502   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean    │  0.57592   │ 0.6088486412455061   │
# ╘═════════════════════╧════════════╧══════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth
# Epoch 3:
# ╒═════════════════════╤════════════╤══════════════════════╕
# │ Metric              │      Train │ Test                 │
# ╞═════════════════════╪════════════╪══════════════════════╡
# │ loss                │ 50.4888    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_id             │ 21.6134    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_gender         │  0.0547901 │ 0.05433643562719226  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_gender      │  0.174435  │ 0.1005083154886961   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_emotion        │  0.18426   │ 0.19004158303141594  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_emotion     │  0.427076  │ 0.5433029308915138   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_pose           │  0.0198862 │ 0.020147281931713223 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_pose        │  0.0472458 │ 0.033933790400624275 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair    │  0.221981  │ 0.24726754240691662  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_facial_hair │  0.478101  │ 0.2576473169028759   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles     │  0.208435  │ 0.21447329595685005  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_spectacles  │  0.478622  │ 0.31016359105706215  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_gender          │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles      │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair     │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_pose            │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_emotion         │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine       │  0.574126  │ 0.5957320113175137   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean    │  0.600217  │ 0.6277670583318216   │
# ╘═════════════════════╧════════════╧══════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth
# Epoch 4:
# ╒═════════════════════╤════════════╤══════════════════════╕
# │ Metric              │      Train │ Test                 │
# ╞═════════════════════╪════════════╪══════════════════════╡
# │ loss                │ 43.6141    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_id             │ 22.1606    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_gender         │  0.0503118 │ 0.06492710812017322  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_gender      │  0.0831232 │ 0.07146874675527215  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_emotion        │  0.179956  │ 0.20759722217917442  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_emotion     │  0.318808  │ 0.22525029815733433  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_pose           │  0.019606  │ 0.038250636658631265 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_pose        │  0.0671242 │ 0.10663163475692272  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair    │  0.220824  │ 0.2762548141181469   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_facial_hair │  0.247527  │ 0.21341731771826744  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles     │  0.21045   │ 0.26490601897239685  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_spectacles  │  0.307293  │ 0.2322281263768673   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_gender          │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles      │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair     │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_pose            │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_emotion         │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine       │  0.562285  │ 0.5683770863406614   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean    │  0.564276  │ 0.6204740725597065   │
# ╘═════════════════════╧════════════╧══════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth
# Epoch 5:
# ╒═════════════════════╤════════════╤══════════════════════╕
# │ Metric              │      Train │ Test                 │
# ╞═════════════════════╪════════════╪══════════════════════╡
# │ loss                │ 42.2327    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_id             │ 22.5848    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_gender         │  0.047077  │ 0.058940515387803316 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_gender      │  0.065657  │ 0.0724457511678338   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_emotion        │  0.178455  │ 0.23400859907269478  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_emotion     │  0.199469  │ 0.2091339137405157   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_pose           │  0.0204334 │ 0.02688374719582498  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_pose        │  0.0973292 │ 0.08997441921383142  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair    │  0.221982  │ 0.20643038302659988  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_facial_hair │  0.227505  │ 0.3525954596698284   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles     │  0.212204  │ 0.2240593135356903   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_spectacles  │  0.233687  │ 0.22527619637548923  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_gender          │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles      │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair     │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_pose            │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_emotion         │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine       │  0.573976  │ 0.581863985283453    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean    │  0.582408  │ 0.6404388310671554   │
# ╘═════════════════════╧════════════╧══════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth
# Epoch 6:
# ╒═════════════════════╤════════════╤═════════════════════╕
# │ Metric              │      Train │ Test                │
# ╞═════════════════════╪════════════╪═════════════════════╡
# │ loss                │ 41.6178    │ -                   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_id             │ 23.0556    │ -                   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_gender         │  0.0529272 │ 0.05765842227265239 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_gender      │  0.063071  │ 0.0647991830483079  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_emotion        │  0.180936  │ 0.17226154915988445 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_emotion     │  0.188321  │ 0.22255705296993256 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_pose           │  0.0184496 │ 0.02031302929390222 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_pose        │  0.0615268 │ 0.03154071816243231 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_facial_hair    │  0.219775  │ 0.3071352653205395  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.24458   │ 0.30233224108815193 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_spectacles     │  0.210253  │ 0.28942625131458044 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.22443   │ 0.22040687128901482 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_gender          │  1         │ 1.0                 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_spectacles      │  1         │ 1.0                 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_facial_hair     │  1         │ 1.0                 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_pose            │  1         │ 1.0                 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_emotion         │  1         │ 1.0                 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_id_cosine       │  0.570869  │ 0.6239890799560728  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.590419  │ 0.6787780391997562  │
# ╘═════════════════════╧════════════╧═════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth
# Epoch 7:
# ╒═════════════════════╤════════════╤══════════════════════╕
# │ Metric              │      Train │ Test                 │
# ╞═════════════════════╪════════════╪══════════════════════╡
# │ loss                │ 40.3263    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_id             │ 23.5557    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_gender         │  0.0461591 │ 0.051363477017730474 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_gender      │  0.0604008 │ 0.07211451698094606  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_emotion        │  0.175885  │ 0.197012796998024    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_emotion     │  0.184684  │ 0.24096998013556004  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_pose           │  0.0180095 │ 0.02306599565781653  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_pose        │  0.0268601 │ 0.02204061788506806  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair    │  0.216459  │ 0.23556490056216717  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_facial_hair │  0.23111   │ 0.23038575239479542  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles     │  0.199398  │ 0.18597701285034418  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_spectacles  │  0.215232  │ 0.23495138809084892  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_gender          │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles      │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair     │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_pose            │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_emotion         │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine       │  0.566761  │ 0.6671280065046091   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean    │  0.590839  │ 0.6996037036307814   │
# ╘═════════════════════╧════════════╧══════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth
# Epoch 8:
# ╒═════════════════════╤════════════╤══════════════════════╕
# │ Metric              │      Train │ Test                 │
# ╞═════════════════════╪════════════╪══════════════════════╡
# │ loss                │ 40.9002    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_id             │ 25.0106    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_gender         │  0.0408933 │ 0.05553688621148467  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_gender      │  0.0578664 │ 0.06797315599396825  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_emotion        │  0.16946   │ 0.1988143678754568   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_emotion     │  0.182088  │ 0.2137811779975891   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_pose           │  0.0159398 │ 0.03137841646093875  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_pose        │  0.0220352 │ 0.020351265440694988 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair    │  0.212353  │ 0.2623640652745962   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_facial_hair │  0.223281  │ 0.21564772725105286  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles     │  0.182052  │ 0.2436838448047638   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_spectacles  │  0.209519  │ 0.20046810992062092  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_gender          │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles      │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair     │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_pose            │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_emotion         │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine       │  0.575283  │ 0.6731284007401608   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean    │  0.594712  │ 0.6918920692404977   │
# ╘═════════════════════╧════════════╧══════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth
# Epoch 9:
# ╒═════════════════════╤════════════╤═════════════════════╕
# │ Metric              │      Train │ Test                │
# ╞═════════════════════╪════════════╪═════════════════════╡
# │ loss                │ 41.2571    │ -                   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_id             │ 25.5032    │ -                   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_gender         │  0.0437204 │ 0.04984965268522501 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_gender      │  0.0582683 │ 0.06205354677513242 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_emotion        │  0.16773   │ 0.2001870647072792  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_emotion     │  0.183837  │ 0.18890485540032387 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_pose           │  0.0163142 │ 0.04090949997771531 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_pose        │  0.0209375 │ 0.01993336109444499 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_facial_hair    │  0.207103  │ 0.23848248273134232 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.220154  │ 0.21291108801960945 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_spectacles     │  0.171568  │ 0.30653547681868076 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.207279  │ 0.2048986740410328  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_gender          │  1         │ 1.0                 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_spectacles      │  1         │ 1.0                 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_facial_hair     │  1         │ 1.0                 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_pose            │  1         │ 1.0                 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_emotion         │  1         │ 1.0                 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_id_cosine       │  0.60737   │ 0.6129216880449455  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.598447  │ 0.6583139249802576  │
# ╘═════════════════════╧════════════╧═════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth
# Epoch 10:
# ╒═════════════════════╤════════════╤═════════════════════╕
# │ Metric              │      Train │ Test                │
# ╞═════════════════════╪════════════╪═════════════════════╡
# │ loss                │ 41.2183    │ -                   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_id             │ 25.7383    │ -                   │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_gender         │  0.0394012 │ 0.05360110104084015 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_gender      │  0.0593561 │ 0.0660295132547617  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_emotion        │  0.16256   │ 0.20728156901896    │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_emotion     │  0.18494   │ 0.1850739736109972  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_pose           │  0.0162046 │ 0.01981971738860011 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_pose        │  0.0206248 │ 0.0218025678768754  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_facial_hair    │  0.20624   │ 0.23438492696732283 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.219237  │ 0.21622991748154163 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_spectacles     │  0.162495  │ 0.18523922376334667 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.205769  │ 0.19692916981875896 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_gender          │  1         │ 1.0                 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_spectacles      │  1         │ 1.0                 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_facial_hair     │  1         │ 1.0                 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_pose            │  1         │ 1.0                 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_emotion         │  1         │ 1.0                 │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_id_cosine       │  0.600048  │ 0.6889183725585515  │
# ├─────────────────────┼────────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.622221  │ 0.714714160174488   │
# ╘═════════════════════╧════════════╧═════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth
# Epoch 11:
# ╒═════════════════════╤════════════╤══════════════════════╕
# │ Metric              │      Train │ Test                 │
# ╞═════════════════════╪════════════╪══════════════════════╡
# │ loss                │ 41.0964    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_id             │ 25.2683    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_gender         │  0.0390189 │ 0.06128583196550608  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_gender      │  0.0683214 │ 0.08147524483501911  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_emotion        │  0.165389  │ 0.1870798710733652   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_emotion     │  0.194098  │ 0.18859855644404888  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_pose           │  0.0173704 │ 0.01769486488774419  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_pose        │  0.0203985 │ 0.020896609406918287 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair    │  0.201878  │ 0.2348236981779337   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_facial_hair │  0.217272  │ 0.22854074649512768  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles     │  0.160802  │ 0.1731757763773203   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_spectacles  │  0.208044  │ 0.20011900551617146  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_gender          │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles      │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair     │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_pose            │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_emotion         │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine       │  0.608891  │ 0.7476718093132018   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean    │  0.627218  │ 0.7437200954541718   │
# ╘═════════════════════╧════════════╧══════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth
# Epoch 12:
# ╒═════════════════════╤════════════╤══════════════════════╕
# │ Metric              │      Train │ Test                 │
# ╞═════════════════════╪════════════╪══════════════════════╡
# │ loss                │ 41.0568    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_id             │ 25.7609    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_gender         │  0.0342531 │ 0.058418803848326206 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_gender      │  0.0677484 │ 0.06651003193110228  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_emotion        │  0.160118  │ 0.2547463309019804   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_emotion     │  0.185154  │ 0.192026874050498    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_pose           │  0.0141128 │ 0.019763381336815655 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_pose        │  0.0207617 │ 0.02146155177615583  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair    │  0.197414  │ 0.2533482266589999   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_facial_hair │  0.217623  │ 0.24427632987499237  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles     │  0.151135  │ 0.2774467598646879   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_spectacles  │  0.20752   │ 0.2051380705088377   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_gender          │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles      │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair     │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_pose            │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_emotion         │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine       │  0.606372  │ 0.6639286162395149   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean    │  0.615449  │ 0.6904129337070983   │
# ╘═════════════════════╧════════════╧══════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth
# Epoch 13:
# ╒═════════════════════╤════════════╤══════════════════════╕
# │ Metric              │      Train │ Test                 │
# ╞═════════════════════╪════════════╪══════════════════════╡
# │ loss                │ 40.7895    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_id             │ 25.5991    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_gender         │  0.0330444 │ 0.04992830869741738  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_gender      │  0.0671756 │ 0.06981990905478597  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_emotion        │  0.157727  │ 0.21524588763713837  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_emotion     │  0.184043  │ 0.18783165328204632  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_pose           │  0.0150128 │ 0.020497432444244623 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_pose        │  0.0209843 │ 0.02197318314574659  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair    │  0.196034  │ 0.29197065718472004  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_facial_hair │  0.21854   │ 0.2452638354152441   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles     │  0.149259  │ 0.1938054822385311   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_spectacles  │  0.204782  │ 0.20304780080914497  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_gender          │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles      │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair     │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_pose            │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_emotion         │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine       │  0.640924  │ 0.6842306193512336   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean    │  0.643893  │ 0.6955258509001135   │
# ╘═════════════════════╧════════════╧══════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth
# Epoch 14:
# ╒═════════════════════╤════════════╤══════════════════════╕
# │ Metric              │      Train │ Test                 │
# ╞═════════════════════╪════════════╪══════════════════════╡
# │ loss                │ 40.1178    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_id             │ 25.3585    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_gender         │  0.0296564 │ 0.060550509952008724 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_gender      │  0.0666439 │ 0.06607642117887735  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_emotion        │  0.153456  │ 0.21385757252573967  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_emotion     │  0.184255  │ 0.18230831995606422  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_pose           │  0.013965  │ 0.02094868232961744  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_pose        │  0.0201415 │ 0.021711667766794562 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair    │  0.190832  │ 0.26277775317430496  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_facial_hair │  0.216342  │ 0.23772423341870308  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles     │  0.134676  │ 0.24690117500722408  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_spectacles  │  0.205151  │ 0.20143746584653854  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_gender          │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles      │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair     │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_pose            │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_emotion         │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine       │  0.601901  │ 0.6833072848348335   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean    │  0.613427  │ 0.6974211311474272   │
# ╘═════════════════════╧════════════╧══════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth
# Epoch 15:
# ╒═════════════════════╤════════════╤══════════════════════╕
# │ Metric              │      Train │ Test                 │
# ╞═════════════════════╪════════════╪══════════════════════╡
# │ loss                │ 39.4286    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_id             │ 24.9293    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_gender         │  0.0307722 │ 0.06214985437691212  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_gender      │  0.064271  │ 0.06628162460401654  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_emotion        │  0.15221   │ 0.19186989590525627  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_emotion     │  0.182553  │ 0.18309791386127472  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_pose           │  0.0125684 │ 0.027875141880940646 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_pose        │  0.0198615 │ 0.02063347038347274  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair    │  0.184744  │ 0.30877307057380676  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_facial_hair │  0.213915  │ 0.22373462282121181  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles     │  0.129566  │ 0.20512539707124233  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_spectacles  │  0.204529  │ 0.20339253544807434  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_gender          │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles      │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair     │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_pose            │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_emotion         │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine       │  0.631935  │ 0.7008168009020866   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean    │  0.618635  │ 0.6991276097109018   │
# ╘═════════════════════╧════════════╧══════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth
# Epoch 16:
# ╒═════════════════════╤════════════╤══════════════════════╕
# │ Metric              │      Train │ Test                 │
# ╞═════════════════════╪════════════╪══════════════════════╡
# │ loss                │ 38.5475    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_id             │ 24.2823    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_gender         │  0.0280881 │ 0.03665373008698225  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_gender      │  0.0627554 │ 0.06585825886577368  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_emotion        │  0.149556  │ 0.16387149319052696  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_emotion     │  0.181663  │ 0.1796678528189659   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_pose           │  0.0117305 │ 0.016576113179326057 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_pose        │  0.0195582 │ 0.019802474533207715 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair    │  0.183006  │ 0.25735785625874996  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_facial_hair │  0.213529  │ 0.24276423640549183  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles     │  0.127901  │ 0.2552605839446187   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_spectacles  │  0.204468  │ 0.20578677579760551  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_gender          │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles      │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair     │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_pose            │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_emotion         │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine       │  0.710254  │ 0.7374202963457487   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean    │  0.696856  │ 0.7440343083124747   │
# ╘═════════════════════╧════════════╧══════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth
# Epoch 17:
# ╒═════════════════════╤════════════╤══════════════════════╕
# │ Metric              │      Train │ Test                 │
# ╞═════════════════════╪════════════╪══════════════════════╡
# │ loss                │ 37.5734    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_id             │ 23.5772    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_gender         │  0.0253303 │ 0.036753744701854885 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_gender      │  0.0627409 │ 0.06579058850184083  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_emotion        │  0.147493  │ 0.15772923734039068  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_emotion     │  0.182577  │ 0.17676950804889202  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_pose           │  0.0114344 │ 0.015608802437782288 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_pose        │  0.0193995 │ 0.02086574351415038  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair    │  0.17717   │ 0.20914440602064133  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_facial_hair │  0.21214   │ 0.23568401858210564  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles     │  0.119323  │ 0.23840893805027008  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_spectacles  │  0.204207  │ 0.20794454030692577  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_gender          │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles      │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair     │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_pose            │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_emotion         │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine       │  0.745308  │ 0.7847331133942786   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean    │  0.747918  │ 0.7683777949455654   │
# ╘═════════════════════╧════════════╧══════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth
# Epoch 18:
# ╒═════════════════════╤════════════╤══════════════════════╕
# │ Metric              │      Train │ Test                 │
# ╞═════════════════════╪════════════╪══════════════════════╡
# │ loss                │ 36.4397    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_id             │ 22.6864    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_gender         │  0.0241528 │ 0.03946047893259674  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_gender      │  0.0624131 │ 0.06647340627387166  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_emotion        │  0.144149  │ 0.15847676433622837  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_emotion     │  0.180671  │ 0.17602549865841866  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_pose           │  0.0108149 │ 0.014659641950856894 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_pose        │  0.0194786 │ 0.020083751063793898 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair    │  0.170409  │ 0.24657485261559486  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_facial_hair │  0.211098  │ 0.23418927006423473  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles     │  0.113672  │ 0.19596072286367416  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_spectacles  │  0.204756  │ 0.21119959466159344  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_gender          │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles      │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_facial_hair     │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_pose            │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_emotion         │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_cosine       │  0.748327  │ 0.7788889351369279   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_id_euclidean    │  0.731968  │ 0.7879198792871097   │
# ╘═════════════════════╧════════════╧══════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth
# Epoch 19:
# ╒═════════════════════╤════════════╤══════════════════════╕
# │ Metric              │      Train │ Test                 │
# ╞═════════════════════╪════════════╪══════════════════════╡
# │ loss                │ 35.4849    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_id             │ 21.7985    │ -                    │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_gender         │  0.0254778 │ 0.10780904459534213  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_gender      │  0.062712  │ 0.06685769697651267  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_emotion        │  0.144266  │ 0.15495548117905855  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_emotion     │  0.181606  │ 0.17645904794335365  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_pose           │  0.0101332 │ 0.019364144536666572 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_pose        │  0.0192418 │ 0.019612449454143643 │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_facial_hair    │  0.164322  │ 0.2492480967193842   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_facial_hair │  0.209205  │ 0.23171030171215534  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_spectacles     │  0.109278  │ 0.19271844625473022  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ loss_da_spectacles  │  0.207268  │ 0.2068239003419876   │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_gender          │  1         │ 1.0                  │
# ├─────────────────────┼────────────┼──────────────────────┤
# │ auc_spectacles      │  1         │ 1.0                  │
# ...
# │ loss                │ 11.2319      │ -                    │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_id             │  2.13701     │ -                    │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_gender         │  0.00110207  │ 0.09305084948755393  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_gender      │  0.0640261   │ 0.06539557175710797  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_emotion        │  0.0200844   │ 1.1451941281557083   │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_emotion     │  0.185557    │ 0.18169326893985271  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_pose           │  0.000497171 │ 0.027478406333102612 │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_pose        │  0.0194948   │ 0.019913642085157335 │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_facial_hair    │  0.0137863   │ 0.6168725125389756   │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_facial_hair │  0.218179    │ 0.2258475385606289   │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_spectacles     │  0.00764369  │ 0.10858008952345699  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_spectacles  │  0.208877    │ 0.20763716101646423  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_gender          │  1           │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_spectacles      │  1           │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_facial_hair     │  1           │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_pose            │  1           │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_emotion         │  1           │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_id_cosine       │  0.999256    │ 0.9614588577273924   │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_id_euclidean    │  0.995016    │ 0.935737945195011    │
# ╘═════════════════════╧══════════════╧══════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth
# Task 'pose' chỉ chứa một lớp ([1]). Không thể tính AUC.
# Epoch 115:
# ╒═════════════════════╤══════════════╤═════════════════════╕
# │ Metric              │        Train │ Test                │
# ╞═════════════════════╪══════════════╪═════════════════════╡
# │ loss                │ 11.3172      │ -                   │
# ├─────────────────────┼──────────────┼─────────────────────┤
# │ loss_id             │  2.2045      │ -                   │
# ├─────────────────────┼──────────────┼─────────────────────┤
# │ loss_gender         │  0.00108805  │ 0.08091148018866079 │
# ├─────────────────────┼──────────────┼─────────────────────┤
# │ loss_da_gender      │  0.0643312   │ 0.0653611752204597  │
# ├─────────────────────┼──────────────┼─────────────────────┤
# │ loss_emotion        │  0.0206062   │ 1.1628409326076508  │
# ├─────────────────────┼──────────────┼─────────────────────┤
# │ loss_da_emotion     │  0.185308    │ 0.18156541883945465 │
# ├─────────────────────┼──────────────┼─────────────────────┤
# │ loss_pose           │  0.000457857 │ 0.02796306991149322 │
# ├─────────────────────┼──────────────┼─────────────────────┤
# │ loss_da_pose        │  0.0194943   │ 0.01989640318788588 │
# ├─────────────────────┼──────────────┼─────────────────────┤
# │ loss_facial_hair    │  0.0142557   │ 0.6422735099404235  │
# ├─────────────────────┼──────────────┼─────────────────────┤
# │ loss_da_facial_hair │  0.218508    │ 0.22583110071718693 │
# ├─────────────────────┼──────────────┼─────────────────────┤
# │ loss_spectacles     │  0.00749776  │ 0.10814995056716725 │
# ├─────────────────────┼──────────────┼─────────────────────┤
# │ loss_da_spectacles  │  0.208976    │ 0.20776708237826824 │
# ├─────────────────────┼──────────────┼─────────────────────┤
# │ auc_gender          │  1           │ 1.0                 │
# ├─────────────────────┼──────────────┼─────────────────────┤
# │ auc_spectacles      │  1           │ 1.0                 │
# ├─────────────────────┼──────────────┼─────────────────────┤
# │ auc_facial_hair     │  1           │ 1.0                 │
# ├─────────────────────┼──────────────┼─────────────────────┤
# │ auc_pose            │  0.99        │ 1.0                 │
# ├─────────────────────┼──────────────┼─────────────────────┤
# │ auc_emotion         │  1           │ 1.0                 │
# ├─────────────────────┼──────────────┼─────────────────────┤
# │ auc_id_cosine       │  0.999293    │ 0.9644656669781636  │
# ├─────────────────────┼──────────────┼─────────────────────┤
# │ auc_id_euclidean    │  0.993409    │ 0.935904972823124   │
# ╘═════════════════════╧══════════════╧═════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth
# Task 'gender' chỉ chứa một lớp ([1]). Không thể tính AUC.
# Epoch 116:
# ╒═════════════════════╤══════════════╤══════════════════════╕
# │ Metric              │        Train │ Test                 │
# ╞═════════════════════╪══════════════╪══════════════════════╡
# │ loss                │ 11.2531      │ -                    │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_id             │  2.18936     │ -                    │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_gender         │  0.000957775 │ 0.08555752528991434  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_gender      │  0.0642758   │ 0.06535132648423314  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_emotion        │  0.0169894   │ 1.2177460491657257   │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_emotion     │  0.185337    │ 0.18156017735600471  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_pose           │  0.000474538 │ 0.027091930112874252 │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_pose        │  0.0194743   │ 0.019909569062292576 │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_facial_hair    │  0.0133437   │ 0.5664454556972487   │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_facial_hair │  0.21861     │ 0.22570792958140373  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_spectacles     │  0.00755281  │ 0.11880268470849842  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_spectacles  │  0.20899     │ 0.20777957700192928  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_gender          │  0.99        │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_spectacles      │  1           │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_facial_hair     │  1           │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_pose            │  1           │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_emotion         │  1           │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_id_cosine       │  0.999062    │ 0.9609776683623551   │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_id_euclidean    │  0.995828    │ 0.9341569054532766   │
# ╘═════════════════════╧══════════════╧══════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth
# Task 'gender' chỉ chứa một lớp ([1]). Không thể tính AUC.
# Epoch 117:
# ╒═════════════════════╤══════════════╤══════════════════════╕
# │ Metric              │        Train │ Test                 │
# ╞═════════════════════╪══════════════╪══════════════════════╡
# │ loss                │ 11.2763      │ -                    │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_id             │  2.1449      │ -                    │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_gender         │  0.00109806  │ 0.08035843904144713  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_gender      │  0.0642016   │ 0.0653482316993177   │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_emotion        │  0.0194484   │ 1.2131657972931862   │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_emotion     │  0.185048    │ 0.18148453906178474  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_pose           │  0.000487389 │ 0.026043413774459623 │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_pose        │  0.0194847   │ 0.019910012022592127 │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_facial_hair    │  0.016367    │ 0.6468813763058279   │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_facial_hair │  0.218653    │ 0.2255235482007265   │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_spectacles     │  0.00909217  │ 0.11577211017720401  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_spectacles  │  0.208715    │ 0.20778578333556652  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_gender          │  0.99        │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_spectacles      │  1           │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_facial_hair     │  1           │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_pose            │  1           │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_emotion         │  1           │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_id_cosine       │  0.999198    │ 0.9626342091637087   │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_id_euclidean    │  0.992983    │ 0.9331102265267155   │
# ╘═════════════════════╧══════════════╧══════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth
# Task 'gender' chỉ chứa một lớp ([1]). Không thể tính AUC.
# Epoch 118:
# ╒═════════════════════╤══════════════╤══════════════════════╕
# │ Metric              │        Train │ Test                 │
# ╞═════════════════════╪══════════════╪══════════════════════╡
# │ loss                │ 11.3189      │ -                    │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_id             │  2.16564     │ -                    │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_gender         │  0.00108349  │ 0.08893792894377839  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_gender      │  0.0638809   │ 0.06537858117371798  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_emotion        │  0.0190963   │ 1.2298094108700752   │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_emotion     │  0.185147    │ 0.18156076036393642  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_pose           │  0.000535347 │ 0.027449105753476033 │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_pose        │  0.019476    │ 0.019905949826352298 │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_facial_hair    │  0.0172019   │ 0.6005951272090897   │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_facial_hair │  0.218606    │ 0.22577623277902603  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_spectacles     │  0.0114518   │ 0.10769441048614681  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_spectacles  │  0.208893    │ 0.2078529465943575   │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_gender          │  0.99        │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_spectacles      │  1           │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_facial_hair     │  1           │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_pose            │  1           │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_emotion         │  1           │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_id_cosine       │  0.999375    │ 0.9625103608428169   │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_id_euclidean    │  0.994756    │ 0.9315707844593479   │
# ╘═════════════════════╧══════════════╧══════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth
# Task 'pose' chỉ chứa một lớp ([1]). Không thể tính AUC.
# Epoch 119:
# ╒═════════════════════╤══════════════╤══════════════════════╕
# │ Metric              │        Train │ Test                 │
# ╞═════════════════════╪══════════════╪══════════════════════╡
# │ loss                │ 11.3431      │ -                    │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_id             │  2.17068     │ -                    │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_gender         │  0.000975517 │ 0.0893375836967607   │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_gender      │  0.0642088   │ 0.06535772141069174  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_emotion        │  0.0246793   │ 1.227639228105545    │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_emotion     │  0.185477    │ 0.18151501938700676  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_pose           │  0.000482777 │ 0.03024535218901292  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_pose        │  0.0194813   │ 0.019919756217859685 │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_facial_hair    │  0.0155505   │ 0.5086416693375213   │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_facial_hair │  0.218596    │ 0.22573804296553135  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_spectacles     │  0.00835743  │ 0.1262225664104335   │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ loss_da_spectacles  │  0.209136    │ 0.2078788671642542   │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_gender          │  1           │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_spectacles      │  1           │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_facial_hair     │  1           │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_pose            │  0.99        │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_emotion         │  1           │ 1.0                  │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_id_cosine       │  0.999581    │ 0.9589737969174068   │
# ├─────────────────────┼──────────────┼──────────────────────┤
# │ auc_id_euclidean    │  0.996523    │ 0.9323356818258149   │
# ╘═════════════════════╧══════════════╧══════════════════════╛
# 	Saving model and optimizer state to /kaggle/working/checkpoint/multi/depthmap/models/checkpoint.pth

# %%
# !zip -r output.zip checkpoint/multi/
# Out:
#   adding: checkpoint/multi/ (stored 0%)
#   adding: checkpoint/multi/depthmap/ (stored 0%)
#   adding: checkpoint/multi/depthmap/models/ (stored 0%)
#   adding: checkpoint/multi/depthmap/models/best_cosine_auc_87.pth (deflated 7%)
#   adding: checkpoint/multi/depthmap/models/checkpoint.pth (deflated 19%)
#   adding: checkpoint/multi/depthmap/models/best_euclidean_auc_108.pth (deflated 7%)
#   adding: checkpoint/multi/depthmap/logs/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/Loss_da_spectacles_test/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/Loss_da_spectacles_test/events.out.tfevents.1736971914.f8a87bcf3468.18.8 (deflated 68%)
#   adding: checkpoint/multi/depthmap/logs/Loss_da_spectacles_train/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/Loss_da_spectacles_train/events.out.tfevents.1736971914.f8a87bcf3468.18.7 (deflated 68%)
#   adding: checkpoint/multi/depthmap/logs/Loss_facial_hair_train/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/Loss_facial_hair_train/events.out.tfevents.1736971914.f8a87bcf3468.18.9 (deflated 66%)
#   adding: checkpoint/multi/depthmap/logs/Loss_da_emotion_train/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/Loss_da_emotion_train/events.out.tfevents.1736971914.f8a87bcf3468.18.19 (deflated 66%)
#   adding: checkpoint/multi/depthmap/logs/AUC_cosine_train/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/AUC_cosine_train/events.out.tfevents.1736971914.f8a87bcf3468.18.21 (deflated 63%)
#   adding: checkpoint/multi/depthmap/logs/AUC_facial_hair_train/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/AUC_facial_hair_train/events.out.tfevents.1736971914.f8a87bcf3468.18.29 (deflated 73%)
#   adding: checkpoint/multi/depthmap/logs/Loss_da_pose_test/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/Loss_da_pose_test/events.out.tfevents.1736971914.f8a87bcf3468.18.16 (deflated 64%)
#   adding: checkpoint/multi/depthmap/logs/AUC_pose_test/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/AUC_pose_test/events.out.tfevents.1736971914.f8a87bcf3468.18.32 (deflated 69%)
#   adding: checkpoint/multi/depthmap/logs/AUC_emotion_train/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/AUC_emotion_train/events.out.tfevents.1736971914.f8a87bcf3468.18.33 (deflated 70%)
#   adding: checkpoint/multi/depthmap/logs/Loss_da_pose_train/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/Loss_da_pose_train/events.out.tfevents.1736971914.f8a87bcf3468.18.15 (deflated 64%)
#   adding: checkpoint/multi/depthmap/logs/Loss_da_facial_hair_test/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/Loss_da_facial_hair_test/events.out.tfevents.1736971914.f8a87bcf3468.18.12 (deflated 68%)
#   adding: checkpoint/multi/depthmap/logs/AUC_gender_test/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/AUC_gender_test/events.out.tfevents.1736971914.f8a87bcf3468.18.26 (deflated 70%)
#   adding: checkpoint/multi/depthmap/logs/Loss_da_gender_train/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/Loss_da_gender_train/events.out.tfevents.1736971914.f8a87bcf3468.18.3 (deflated 65%)
#   adding: checkpoint/multi/depthmap/logs/AUC_cosine_test/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/AUC_cosine_test/events.out.tfevents.1736971914.f8a87bcf3468.18.22 (deflated 63%)
#   adding: checkpoint/multi/depthmap/logs/Loss_da_gender_test/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/Loss_da_gender_test/events.out.tfevents.1736971914.f8a87bcf3468.18.4 (deflated 65%)
#   adding: checkpoint/multi/depthmap/logs/AUC_spectacles_test/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/AUC_spectacles_test/events.out.tfevents.1736971914.f8a87bcf3468.18.28 (deflated 72%)
#   adding: checkpoint/multi/depthmap/logs/AUC_facial_hair_test/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/AUC_facial_hair_test/events.out.tfevents.1736971914.f8a87bcf3468.18.30 (deflated 73%)
#   adding: checkpoint/multi/depthmap/logs/Loss_emotion_train/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/Loss_emotion_train/events.out.tfevents.1736971914.f8a87bcf3468.18.17 (deflated 63%)
#   adding: checkpoint/multi/depthmap/logs/events.out.tfevents.1736971866.f8a87bcf3468.18.0 (deflated 62%)
#   adding: checkpoint/multi/depthmap/logs/Loss_facial_hair_test/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/Loss_facial_hair_test/events.out.tfevents.1736971914.f8a87bcf3468.18.10 (deflated 66%)
#   adding: checkpoint/multi/depthmap/logs/Loss_spectacles_train/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/Loss_spectacles_train/events.out.tfevents.1736971914.f8a87bcf3468.18.5 (deflated 65%)
#   adding: checkpoint/multi/depthmap/logs/Loss_spectacles_test/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/Loss_spectacles_test/events.out.tfevents.1736971914.f8a87bcf3468.18.6 (deflated 65%)
#   adding: checkpoint/multi/depthmap/logs/AUC_euclidean_test/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/AUC_euclidean_test/events.out.tfevents.1736971914.f8a87bcf3468.18.24 (deflated 65%)
#   adding: checkpoint/multi/depthmap/logs/AUC_spectacles_train/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/AUC_spectacles_train/events.out.tfevents.1736971914.f8a87bcf3468.18.27 (deflated 72%)
#   adding: checkpoint/multi/depthmap/logs/AUC_pose_train/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/AUC_pose_train/events.out.tfevents.1736971914.f8a87bcf3468.18.31 (deflated 69%)
#   adding: checkpoint/multi/depthmap/logs/Loss_pose_train/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/Loss_pose_train/events.out.tfevents.1736971914.f8a87bcf3468.18.13 (deflated 61%)
#   adding: checkpoint/multi/depthmap/logs/Loss_emotion_test/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/Loss_emotion_test/events.out.tfevents.1736971914.f8a87bcf3468.18.18 (deflated 64%)
#   adding: checkpoint/multi/depthmap/logs/AUC_euclidean_train/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/AUC_euclidean_train/events.out.tfevents.1736971914.f8a87bcf3468.18.23 (deflated 65%)
#   adding: checkpoint/multi/depthmap/logs/AUC_emotion_test/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/AUC_emotion_test/events.out.tfevents.1736971914.f8a87bcf3468.18.34 (deflated 70%)
#   adding: checkpoint/multi/depthmap/logs/Loss_da_emotion_test/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/Loss_da_emotion_test/events.out.tfevents.1736971914.f8a87bcf3468.18.20 (deflated 66%)
#   adding: checkpoint/multi/depthmap/logs/Loss_pose_test/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/Loss_pose_test/events.out.tfevents.1736971914.f8a87bcf3468.18.14 (deflated 61%)
#   adding: checkpoint/multi/depthmap/logs/Loss_gender_train/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/Loss_gender_train/events.out.tfevents.1736971914.f8a87bcf3468.18.1 (deflated 63%)
#   adding: checkpoint/multi/depthmap/logs/Loss_gender_test/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/Loss_gender_test/events.out.tfevents.1736971914.f8a87bcf3468.18.2 (deflated 63%)
#   adding: checkpoint/multi/depthmap/logs/Loss_da_facial_hair_train/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/Loss_da_facial_hair_train/events.out.tfevents.1736971914.f8a87bcf3468.18.11 (deflated 68%)
#   adding: checkpoint/multi/depthmap/logs/AUC_gender_train/ (stored 0%)
#   adding: checkpoint/multi/depthmap/logs/AUC_gender_train/events.out.tfevents.1736971914.f8a87bcf3468.18.25 (deflated 70%)
